# %%
import pandas as pd
import numpy as np
df = pd.read_csv("heart_2020_cleaned.csv")
display(df.head(20))
# Out:
#    HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0            No  16.60     Yes              No     No             3.0
# 1            No  20.34      No              No    Yes             0.0
# 2            No  26.58     Yes              No     No            20.0
# 3            No  24.21      No              No     No             0.0
# 4            No  23.71      No              No     No            28.0
# 5           Yes  28.87     Yes              No     No             6.0
# 6            No  21.63      No              No     No            15.0
# 7            No  31.64     Yes              No     No             5.0
# 8            No  26.45      No              No     No             0.0
# 9            No  40.69      No              No     No             0.0
# 10          Yes  34.30     Yes              No     No            30.0
# 11           No  28.71     Yes              No     No             0.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79649 entries, 0 to 79648
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   HeartDisease      79649 non-null  object
#  1   BMI               79649 non-null  float64
#  2   Smoking           79649 non-null  object
#  3   AlcoholDrinking   79649 non-null  object
#  4   Stroke            79649 non-null  object
#  5   PhysicalHealth    79649 non-null  float64
#  6   MentalHealth      79649 non-null  float64
#  7   DiffWalking       79649 non-null  object
#  8   Sex               79649 non-null  object
#  9   AgeCategory       79649 non-null  object
#  10  Race              79648 non-null  object
#  11  Diabetic          79648 non-null  object
#  12  PhysicalActivity  79648 non-null  object
#  13  GenHealth         79648 non-null  object
#  14  SleepTime         79648 non-null  float64
#  15  Asthma            79648 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# HeartDisease        0
# BMI                 0
# Smoking             0
# AlcoholDrinking     0
# Stroke              0
# PhysicalHealth      0
# MentalHealth        0
# DiffWalking         0
# Sex                 0
# AgeCategory         0
# Race                1
# Diabetic            1
# PhysicalActivity    1
# GenHealth           1
# SleepTime           1
# Asthma              1
# KidneyDisease       1
# SkinCancer          1
# dtype: int64

# %%
for column_name in df.columns:
    unique_values = len(df[column_name].unique())
    print("Feature '{column_name}' has '{unique_values}' unique values".format(column_name = column_name,
                                                                                           unique_values=unique_values))
# Out:
# Feature 'HeartDisease' has '2' unique values
# Feature 'BMI' has '2651' unique values
# Feature 'Smoking' has '2' unique values
# Feature 'AlcoholDrinking' has '2' unique values
# Feature 'Stroke' has '2' unique values
# Feature 'PhysicalHealth' has '31' unique values
# Feature 'MentalHealth' has '31' unique values
# Feature 'DiffWalking' has '2' unique values
# Feature 'Sex' has '2' unique values
# Feature 'AgeCategory' has '14' unique values
# Feature 'Race' has '7' unique values
# Feature 'Diabetic' has '5' unique values
# Feature 'PhysicalActivity' has '3' unique values
# Feature 'GenHealth' has '6' unique values
# Feature 'SleepTime' has '24' unique values
# Feature 'Asthma' has '3' unique values
# Feature 'KidneyDisease' has '3' unique values
# Feature 'SkinCancer' has '3' unique values

# %%
df.describe().style\
    .background_gradient(cmap="coolwarm")\
    .highlight_max(axis=0, color='purple')\
    .highlight_min(axis=0, color='blue')
# Out:
# <style type="text/css">
# #T_a1455_row0_col0, #T_a1455_row0_col1, #T_a1455_row0_col2, #T_a1455_row0_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
#   background-color: purple;
# }
# #T_a1455_row1_col0, #T_a1455_row1_col1, #T_a1455_row1_col2, #T_a1455_row1_col3, #T_a1455_row2_col1, #T_a1455_row2_col2, #T_a1455_row2_col3, #T_a1455_row3_col0, #T_a1455_row4_col0, #T_a1455_row4_col3, #T_a1455_row5_col0, #T_a1455_row5_col3, #T_a1455_row6_col0, #T_a1455_row6_col1, #T_a1455_row6_col2, #T_a1455_row6_col3, #T_a1455_row7_col0, #T_a1455_row7_col1, #T_a1455_row7_col2, #T_a1455_row7_col3 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_a1455_row2_col0, #T_a1455_row3_col1, #T_a1455_row3_col2, #T_a1455_row3_col3, #T_a1455_row4_col1, #T_a1455_row4_col2, #T_a1455_row5_col1, #T_a1455_row5_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
#   background-color: blue;
# }
# </style>
# <table id="T_a1455" class="dataframe">
#   <thead>
#     <tr>
# ...

# %% [markdown]
# **Insights:**
# The describe() function give the summary statistics about the numerical columns in the dataset. It helps in understanding the distribution, spread, and possible anomalies in your data.
#
# We benifited from:
# - The average of Sleeping Time = 7 hours.
# - The range between MIN , MAX Sleep time of peeple.
# - The min value in Physical Health & Mental Health is 0 and it is real information.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

heartdisease_counts = df['HeartDisease'].value_counts()
labels = heartdisease_counts.index     # ['No', 'Yes']
sizes = heartdisease_counts.values     # عدد الأشخاص
colors = ['#4285f4','#ff0000']        # ألوان مخصصة (أزرق = No, أحمر = Yes)
explode = [0, 0.2] if 'No' in labels.tolist() else [0.2, 0]

fig, axes = plt.subplots(1, 2, figsize=(12, 6))  #صف واحد و عمودين

axes[0].pie(
    sizes,
    labels=labels,
    colors=colors,
    autopct='%1.1f%%',          # عرض النسبة
    explode=explode
)

axes[0].set_title("Heart Disease Distribution (Pie)", fontsize=12, weight='bold')
bar_colors = {'No': '#4285f4', 'Yes': '#ff0000'}
sns.countplot(data=df, x='HeartDisease',palette=bar_colors, ax=axes[1])
axes[1].set_title("Heart Disease Count (Bar Chart)", fontsize=12, weight='bold')
axes[1].set_xlabel("Heart Disease")
axes[1].set_ylabel("Number of People")
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-13-1160872457.py:23: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='HeartDisease',palette=bar_colors, ax=axes[1])

# %% [markdown]
# **Insights: **
# - In Pie chart, The percentage of patients who don't have the heart disease > the people with heart disease with percentaage
# 91.4% to 8.6%.
# - In Bar chart, The actual numbers of people, no just the percentage.

# %%
bar_colors = {'No': '#4285f4', 'Yes': '#ff0000'}
sns.countplot(data=df, x='Sex',hue='HeartDisease', palette=bar_colors)
plt.title("Heart Disease by Gender")
plt.show()

# %% [markdown]
# **Insights: **
# - Comparison between the gender of patients, so the males patients percentage > females patients.

# %%
import matplotlib.cm as cm
filtered_df = df[
    (df['HeartDisease'] == 'Yes') & (df['KidneyDisease'] == 'Yes')
]
age_kidney_heart_counts = filtered_df['AgeCategory'].value_counts().sort_index() #نعد عدد الناس في كل AgeCategory و نرتب الفئات العمرية بشكل منطقي

num_bars = len(age_kidney_heart_counts)
colors = cm.Blues(np.linspace(0.2, 0.7, num_bars))

plt.figure(figsize=(12,6))
bars = plt.bar(
    age_kidney_heart_counts.index,
    age_kidney_heart_counts.values,
    color=colors
)

plt.title("People with Both Heart Disease & Kidney Disease by Age Category", fontsize=12, weight='bold')
plt.xlabel("Age Category")
plt.ylabel("Number of People")
plt.grid(axis='y', linestyle='--', alpha=0.3)

# إضافة أرقام فوق الأعمدة
for bar in bars:
    yvalue = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yvalue + 5, int(yvalue), ha='center', fontsize=7, fontweight='bold') # بيضيف رقم فوق كل عمود

plt.tight_layout()
plt.show()

# %% [markdown]
# **Insights: **
# - Sort the numbers of people who have both heart disease & kidney disease together by the age category to get the higher number of pateints in which age categoty.
# - So the higher number of heart-kidney patients was in age category = 80 or older with number of people = 786.
# - The lower number of heart-kidney patients was in age category = 25 - 29 with number of youths = 5.

# %%
group_total = df.groupby(['Smoking', 'AlcoholDrinking'])['HeartDisease'].value_counts(normalize=True).unstack().fillna(0)

disease_rate = group_total['Yes'].unstack()       # ناخد النسبة المصابين فقط و يحولهم اه او لا ف اعمدة بدل ماتكون index

# Heatmap
plt.figure(figsize=(7,5))
sns.heatmap(disease_rate, annot=True, cmap="Reds", fmt=".2f")  #annot بتعرض القيم الرقمية داخل كل خانة

plt.title("Heart Disease Rate by Smoking & Alcohol", fontsize=12, weight='bold')
plt.xlabel("Alcohol Drinking")
plt.ylabel("Smoking")
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insights: **
# - The people who Smokking and don't drink alcohol was the higher percantage who have heart disease which mean that the alcohol may not a main reason to the heart disease like smoking.
# - Also the lower percentage of people who have heart disease is drink alcohol but don't smoke.

# %%
#plt.figure(figsize=(12,5))
#sns.histplot(data=df, x='SleepTime', hue='HeartDisease', kde=False, bins=20, palette=['#4285f4', '#ea4335'], alpha=0.6)
#plt.title("Histogram of Sleep Time by Heart Disease")

# %% [markdown]
# # **Encodinig dataset**

# %% [markdown]
# Befor Encoding We wanted to know the percentage of infection in both sexes in each age group.

# %%
age_order = ['18-24', '25-29', '30-34', '35-39',
             '40-44', '45-49', '50-54', '55-59',
             '60-64', '65-69', '70-74', '75-79', '80 or older']

df['AgeCategory'] = pd.Categorical(df['AgeCategory'], categories=age_order, ordered=True)

grouped = df.groupby(['AgeCategory', 'Sex'])['HeartDisease'].value_counts(normalize=True).rename('Proportion').reset_index()
heart_patients = grouped[grouped['HeartDisease'] == 'Yes']

plt.figure(figsize=(12,6))
sns.barplot(data=heart_patients, x='AgeCategory', y='Proportion', hue='Sex')

plt.title("Heart Disease Percentage by Age and Sex")
plt.xlabel("Age Category")
plt.ylabel("Percentage with Heart Disease")
plt.xticks(rotation=45)

plt.legend(title="Sex")

plt.show()
# Out:
# /tmp/ipython-input-17-1796014167.py:7: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = df.groupby(['AgeCategory', 'Sex'])['HeartDisease'].value_counts(normalize=True).rename('Proportion').reset_index()

# %% [markdown]
# We also see that the chance of infection increases with age, especially among males.

# %%
#df['AgeCategory'].describe()

# %%
df["Diabetic"] = df["Diabetic"].map({
                                  "No": 0,
                                  "No, borderline diabetes": 0.5,
                                  "Yes": 1,
                                  "Yes (during pregnancy)": 1
})

# %%
yes_no_cols = ["HeartDisease","AlcoholDrinking", "Smoking","Stroke",
               "DiffWalking",  "PhysicalActivity",
               "Asthma", "KidneyDisease", "SkinCancer" ]

for col in yes_no_cols:
    df[col] = df[col].map({"Yes": 1, "No": 0})

# %%
for col in yes_no_cols:
    print(f"{col}: {df[col].unique()}")
# Out:
# HeartDisease: [0 1]
# AlcoholDrinking: [0 1]
# Smoking: [1 0]
# Stroke: [0 1]
# DiffWalking: [0 1]
# PhysicalActivity: [ 1.  0. nan]
# Asthma: [ 1.  0. nan]
# KidneyDisease: [ 0.  1. nan]
# SkinCancer: [ 1.  0. nan]

# %%
df[yes_no_cols].isna().sum()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

corr_cols = [
    "HeartDisease", "BMI", "Smoking", "AlcoholDrinking",
    "Stroke", "Asthma", "Diabetic", "DiffWalking",
    "SkinCancer", "PhysicalHealth", "MentalHealth", "SleepTime"
]

corr = df[corr_cols].corr().abs()

sns.heatmap(corr, annot=True,  cmap="Blues_r", vmin=0, vmax=1, fmt=".2f")
plt.title("Correlation with Heart Disease and Other Numeric Features")
plt.show()

# %%
df[corr_cols].dtypes
# Out:
# HeartDisease         int64
# BMI                float64
# Smoking              int64
# AlcoholDrinking      int64
# Stroke               int64
# Asthma             float64
# Diabetic           float64
# DiffWalking          int64
# SkinCancer         float64
# PhysicalHealth     float64
# MentalHealth       float64
# SleepTime          float64
# dtype: object

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(13, 5))
sns.histplot(data=df[df["HeartDisease"] == 0], x="SleepTime", kde=True,stat="density", alpha=0.5, color="#4285f4", label="No HeartDisease", ax=ax)
sns.histplot(data=df[df["HeartDisease"] == 1], x="SleepTime", kde=True, stat="density", alpha=0.5, color="#ea4335", label="HeartDisease", ax=ax)


ax.set_xlabel("SleepTime (hours)")
ax.set_ylabel("Count")
ax.legend(bbox_to_anchor=(1.02, 1), loc=2, borderaxespad=0.)


ax.set_xlim(0, 15)

plt.show()

# %% [markdown]
# **Insights:**
# - Although they are present in the "no heart disease" group, these peaks appear lower in the afternoon and higher in the evening, which may indicate greater variation in these sleep patterns.
#
# - There is a significant overlap between the two distributions, meaning that there are only as many individuals with moderate heart disease as there are healthy individuals, and vice versa.

# %%
df_viz = df.copy()
cols_to_convert = ["HeartDisease", "Stroke", "DiffWalking", "KidneyDisease","Diabetic"]
for col in cols_to_convert:
    df_viz[col] = df_viz[col].map({0: "No", 1: "Yes"})

cols = ["Stroke", "DiffWalking", "KidneyDisease","Diabetic"]

fig, axes = plt.subplots(1, len(cols), figsize=(18, 5))
for i, col in enumerate(cols):
    ct = pd.crosstab(df_viz[col], df_viz["HeartDisease"], normalize='index')
    ct = ct[["Yes", "No"]]
    ct.plot(
        kind='bar',
        stacked=True,
        color=["#d62728" , "#1f77b4"] ,
        ax=axes[i],

    )
    axes[i].set_title(f"Heart Disease vs {col}")
    axes[i].set_xlabel(col)
    axes[i].set_ylabel("Proportion")
    axes[i].legend(title="Heart Disease", labels=["Yes", "No"])
    axes[i].set_ylim(0, 1)



plt.tight_layout()
plt.show()

# %% [markdown]
# **Insights:**
#
# - When there is a stroke (Yes): A relatively large percentage (over 0.35 or 35%) of these people have heart disease (red section).
#
#
#
# - When there is difficulty walking (Yes): A much higher percentage (more than 0.2 or 20%) of these people have heart disease (red section).
#
#
#
# - When kidney disease is present (yes): A much higher percentage (more than 0.3 or 30%) of these people have heart disease (red section).
#
#
#
# - When diabetes is present (yes): A much higher percentage (more than 0.2 or 20%) of these people have heart disease (red section).
#
#
#
# - To conclude the general conclusion from all the graphs: All four graphs show a clear, positive relationship between the presence of heart disease and each of the following: stroke, difficulty walking, kidney disease, and diabetes. In other words, people with any of these conditions (stroke, difficulty walking, kidney disease, diabetes) have a significantly higher incidence of heart disease than people without these conditions. This suggests that these variables may be important risk factors for heart disease.

# %% [markdown]
# Relation Between AgeCategory and Heart Disease

# %%
from sklearn.preprocessing import LabelEncoder

cols = ['Sex','AgeCategory','Race','PhysicalActivity','GenHealth']
df[cols] = df[cols].apply(LabelEncoder().fit_transform)

# %%
df.head(20)
# Out:
#     HeartDisease    BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  \
# 0              0  16.60        1                0       0             3.0
# 1              0  20.34        0                0       1             0.0
# 2              0  26.58        1                0       0            20.0
# 3              0  24.21        0                0       0             0.0
# 4              0  23.71        0                0       0            28.0
# 5              1  28.87        1                0       0             6.0
# 6              0  21.63        0                0       0            15.0
# 7              0  31.64        1                0       0             5.0
# 8              0  26.45        0                0       0             0.0
# 9              0  40.69        0                0       0             0.0
# 10             1  34.30        1                0       0            30.0
# 11             0  28.71        1                0       0             0.0
# ...

# %% [markdown]
# Now We Wanted to see the Age distrbution

# %%
df['AgeCategory'].describe()
# Out:
# count    79649.000000
# mean         6.569160
# std          3.590612
# min          0.000000
# 25%          4.000000
# 50%          7.000000
# 75%         10.000000
# max         13.000000
# Name: AgeCategory, dtype: float64

# %%
plt.figure(figsize=(12,6))
sns.histplot(df['AgeCategory'], kde=False, color="#3366FF" )
plt.title("Age Distribution")
plt.xlabel("Age Category")
plt.ylabel("Count(people)")
plt.show()

# %% [markdown]
# **Feature Selection with RandomForestClassifier**

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
X=df.drop(['HeartDisease', "Race", "GenHealth", "MentalHealth"], axis=1)   # columns have low relation in heatmp
y=df['HeartDisease']

model = RandomForestClassifier()
model.fit(X, y)                             # model training

importances = model.feature_importances_            # feature importance
feature_importance = pd.Series(importances, index=X.columns)  # calculate importance for each column

# %%
plt.figure(figsize=(12,6))
feature_importance.sort_values(ascending=False).plot(kind='bar')
plt.title("Feature Importance")
plt.ylabel("Importance Score")
plt.show()

# %% [markdown]
# Now we can see the columns that have the most impact on heart disease and that did not appear in the heatmap.Like Body Mass BMI, Sleep time ,Age Category.

# %%
'''from sklearn.feature_selection import SelectKBest, chi2
import pandas as pd

X=df.drop(['HeartDisease', "Race", "GenHealth", "MentalHealth"], axis=1)   # columns have low relation in heatmp
y=df['HeartDisease']



selector = SelectKBest(score_func=chi2, k=6)
X_new = selector.fit_transform(X, y)

selected_features = X.columns[selector.get_support()]
print("The Best 5 feature:\n", selected_features)  '''
# Out:
# 'from sklearn.feature_selection import SelectKBest, chi2\nimport pandas as pd\n\nX=df.drop([\'HeartDisease\', "Race", "GenHealth", "MentalHealth"], axis=1)   # columns have low relation in heatmp\ny=df[\'HeartDisease\']\n\n\n\nselector = SelectKBest(score_func=chi2, k=6)\nX_new = selector.fit_transform(X, y)\n\nselected_features = X.columns[selector.get_support()]\nprint("The Best 5 feature:\n", selected_features)  '

# %% [markdown]
# As dataset clear that is Imbalance we will use Oversampling: SMOTE (Synthetic Minority Oversampling Technique) to Resample dataset To increase the small sample (infected people):

# %%
#X.isnull().sum()
# Out:
# BMI                 0
# Smoking             0
# AlcoholDrinking     0
# Stroke              0
# PhysicalHealth      0
# DiffWalking         0
# Sex                 0
# AgeCategory         0
# Diabetic            1
# PhysicalActivity    0
# SleepTime           1
# Asthma              1
# KidneyDisease       1
# SkinCancer          1
# dtype: int64

# %%
X.dropna(inplace=True)

# %%
X.isnull().sum()
# Out:
# BMI                 0
# Smoking             0
# AlcoholDrinking     0
# Stroke              0
# PhysicalHealth      0
# DiffWalking         0
# Sex                 0
# AgeCategory         0
# Diabetic            0
# PhysicalActivity    0
# SleepTime           0
# Asthma              0
# KidneyDisease       0
# SkinCancer          0
# dtype: int64

# %%
 #X
# Out:
#          BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  DiffWalking  \
# 0      16.60        1                0       0             3.0            0
# 1      20.34        0                0       1             0.0            0
# 2      26.58        1                0       0            20.0            0
# 3      24.21        0                0       0             0.0            0
# 4      23.71        0                0       0            28.0            1
# ...      ...      ...              ...     ...             ...          ...
# 79643  26.58        1                0       0             0.0            0
# 79644  38.65        0                0       0             0.0            0
# 79645  29.76        1                0       0             4.0            0
# 79646  33.23        1                0       0             0.0            0
# 79647  31.75        1                0       0             0.0            0
#
# ...

# %%
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split

df = df.dropna()

print(X.shape)
print(y.shape)
# drop feature that unimportant and ineffective columns

X = df.drop(['HeartDisease', "Race", "GenHealth", "MentalHealth"], axis=1)   # columns have low relation in heatmp
y=df['HeartDisease']
# Out:
# (79648, 14)
# (79648,)

# %%
# split dataset train and test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

smote = SMOTE(random_state=42)

X_train_resampled ,  y_train_resampled = smote.fit_resample(X_train, y_train)

# %% [markdown]
# **Distribution of Dataset after Resampling**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# ندمج X و y بعد resampling في داتا فريم واحد مؤقت
df_resampled = pd.concat([pd.DataFrame(X_train_resampled, columns=X_train.columns),
                          pd.Series(y_train_resampled, name='HeartDisease')], axis=1)

sns.countplot(data=df_resampled, x='HeartDisease')
plt.title("Distribution of Heart Disease after SMOTE")
plt.xlabel("Heart Disease")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# **What is XGBoost?**
# 🔸 XGBoost stands for eXtreme Gradient Boosting
# 🔸 It is an advanced Boosting algorithm.
#
# **✳️ Its features:**
# Highly accurate classification.
#
# Faster than other Boosting algorithms.
#
# It handles imbalanced data well.
#
# It has the ability to automatically handle missing values.
#
# It supports parallel processing, making it very fast.

# %%
pip install xgboost

# %%
from xgboost import XGBClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

#model
xgb_model = XGBClassifier(random_state=42)
#train
xgb_model.fit(X_train_resampled, y_train_resampled)

# Prediction
y_pred = xgb_model.predict(X_test)

# Evaluation
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.8630257376020087
# Confusion Matrix:
#  [[13386  1174]
#  [ 1008   362]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.92      0.92     14560
#            1       0.24      0.26      0.25      1370
#
#     accuracy                           0.86     15930
#    macro avg       0.58      0.59      0.59     15930
# weighted avg       0.87      0.86      0.87     15930

# %% [markdown]
# **1.XGBoost**
# Precision = 0.24 → The percentage of people who were called sick but actually were sick is small.
#
# Recall = 0.26 → This means the model was only able to detect 26% of those who were actually infected.

# %% [markdown]
# **We wanted to raise the Recall and Precision for the patient category** so we used another models

# %%
from sklearn.linear_model import LogisticRegression

lr_model = LogisticRegression(max_iter=1000)
lr_model.fit(X_train_resampled, y_train_resampled)
y_pred_lr = lr_model.predict(X_test)

print("Logistic Regression:")
print(classification_report(y_test, y_pred_lr))
# Out:
# Logistic Regression:
#               precision    recall  f1-score   support
#
#            0       0.97      0.70      0.81     14560
#            1       0.19      0.74      0.30      1370
#
#     accuracy                           0.71     15930
#    macro avg       0.58      0.72      0.56     15930
# weighted avg       0.90      0.71      0.77     15930

# %% [markdown]
# **2. Logistic Regression:**
# Precision (class 1): 0.19 → Not high.
#
# Recall (class 1): 0.74→ Excellent at detecting infected people.
#
# Accuracy: 71% → Acceptable in cases of imbalanced data.
#
# The model identifies a large number of truly infected people, but it predicts some people have the disease when they are not (this is normal due to the trade-off between Precision and Recall).

# %%
from sklearn.ensemble import RandomForestClassifier

rf_model = RandomForestClassifier(random_state=42)
rf_model.fit(X_train_resampled, y_train_resampled)
y_pred_rf = rf_model.predict(X_test)

print("Random Forest:")
print(classification_report(y_test, y_pred_rf))
# Out:
# Random Forest:
#               precision    recall  f1-score   support
#
#            0       0.92      0.93      0.93     14560
#            1       0.21      0.19      0.20      1370
#
#     accuracy                           0.87     15930
#    macro avg       0.57      0.56      0.56     15930
# weighted avg       0.86      0.87      0.87     15930

# %% [markdown]
# **3. Random Forest:**
# Precision (class 1): 0.21 → Slightly better.
#
# Recall (class 1): 0.19 → Poor at detecting infected people.
#
# Accuracy: 87% → High, but not very important because the data is unbalanced.
#
# The model predicts infected people with low accuracy and does not detect them well. It focuses more on predicting healthy people.

# %%
pip install lightgbm

# %%
from lightgbm import LGBMClassifier

lgb_model = LGBMClassifier(random_state=42)
lgb_model.fit(X_train_resampled, y_train_resampled)
y_pred_lgb = lgb_model.predict(X_test)

print("LightGBM:")
print(classification_report(y_test, y_pred_lgb))
# Out:
# [LightGBM] [Info] Number of positive: 58239, number of negative: 58239
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.035944 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1810
# [LightGBM] [Info] Number of data points in the train set: 116478, number of used features: 14
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# LightGBM:
#               precision    recall  f1-score   support
#
#            0       0.93      0.92      0.93     14560
#            1       0.25      0.29      0.27      1370
#
#     accuracy                           0.87     15930
#    macro avg       0.59      0.60      0.60     15930
# weighted avg       0.87      0.87      0.87     15930

# %% [markdown]
# **4.LightGBM is currently the best balance.**
#
# If our goal is to detect Class 1 infected individuals, LightGBM offers a good compromise between:
#
# Reducing false positives
#
# and detecting a reasonable amount of infected individuals.

# %% [markdown]
# | Model             | Recall (Class 1) | Precision (Class 1) | F1-score (Class 1) |
# | ----------------- | ---------------- | ------------------- | ------------------ |
# | **Logistic**      | **0.74**       | 0.19                | 0.30               |
# | **Random Forest** | 0.19             | 0.21                | 0.20               |
# | **XGBoost**       | 0.26             | 0.24                | 0.25               |
# | **LightGBM**      | **0.29**       | **0.25**         | **0.27**         |
